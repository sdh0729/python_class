# %% [markdown]
# #### seaborn 패키지: 좀 더 편리한 시각화 도구
# - matplotlib의 기능에 스타일을 확장한 파이썬 시각화 도구
# - 패키지는 설치 해야 함(pip install seaborn) 단, 아나콘다 내부에는 이미 설치되어 있음
# - seaborn을 사용하기 위해서는 matplotlib가 import 되어 있어야 함.
# - 스타일 색상을 지원하기위해서 파렛트를 지원
# - 그래프는 대부분 matplotlib에 있는 그래프를 사용하고, seaborn이 몇개의 그래프를 더 가지고 있음

# %%
import pandas as pd 
import numpy as np
import seaborn as sns #seaborn 패키지 임포트
import matplotlib.pyplot as plt # 서브 패키지 pyplot 사용
import folium
import json
# %matplotlib inline
# 경고 메세지 무시 설정
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 한글 문제
# matplotlit의 기본 폰트에서 한글 지원되지 않기 때문에
# matplotlib의 폰트 변경 필요
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

if platform.system()=='Darwin': #맥 OS
    rc('font', family='AppleGothic')
elif platform.system()=='Windows': #윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("anything")

# %%
# 그래프 예제
x=np.linspace(1,14,100)
x
# Out:
# array([ 1.        ,  1.13131313,  1.26262626,  1.39393939,  1.52525253,
#         1.65656566,  1.78787879,  1.91919192,  2.05050505,  2.18181818,
#         2.31313131,  2.44444444,  2.57575758,  2.70707071,  2.83838384,
#         2.96969697,  3.1010101 ,  3.23232323,  3.36363636,  3.49494949,
#         3.62626263,  3.75757576,  3.88888889,  4.02020202,  4.15151515,
#         4.28282828,  4.41414141,  4.54545455,  4.67676768,  4.80808081,
#         4.93939394,  5.07070707,  5.2020202 ,  5.33333333,  5.46464646,
#         5.5959596 ,  5.72727273,  5.85858586,  5.98989899,  6.12121212,
#         6.25252525,  6.38383838,  6.51515152,  6.64646465,  6.77777778,
#         6.90909091,  7.04040404,  7.17171717,  7.3030303 ,  7.43434343,
#         7.56565657,  7.6969697 ,  7.82828283,  7.95959596,  8.09090909,
#         8.22222222,  8.35353535,  8.48484848,  8.61616162,  8.74747475,
#         8.87878788,  9.01010101,  9.14141414,  9.27272727,  9.4040404 ,
#         9.53535354,  9.66666667,  9.7979798 ,  9.92929293, 10.06060606,
#        10.19191919, 10.32323232, 10.45454545, 10.58585859, 10.71717172,
#        10.84848485, 10.97979798, 11.11111111, 11.24242424, 11.37373737,
#        11.50505051, 11.63636364, 11.76767677, 11.8989899 , 12.03030303,
#        12.16161616, 12.29292929, 12.42424242, 12.55555556, 12.68686869,
#        12.81818182, 12.94949495, 13.08080808, 13.21212121, 13.34343434,
#        13.47474747, 13.60606061, 13.73737374, 13.86868687, 14.        ])

# %%
y1 = np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show();

# %% [markdown]
# #### seaborn 스타일링
#  - set_style: background color, grid, spine, tick을 정의하여 그림의 전반적인 모양을 스타일링
#  - set_context: 프리젠테이션이나 보고서와 같은 다양한 매체에 활용할 수 있도록 스타일링
# 1. set_style: 그림의 전반적인 모양 스타일링
#
#   - Built-in Themes (내장 테마) 활용하기
#     - Seaborn에는 5가지 기본 제공 테마가 있음
#     - darkgrid, whitegrid, dark, white, ticks.
#     - 기본값은 darkgrid이지만, 원하는대로 변경이 가능
# 2. sns.despine() 함수
#
#   - 축선 표시 여부 결정하는 함수(right=T/F,left=T/F,top=T/F,bottom=T/F)
#     - 각 속성값이
#     - True 면 : 표시하지 않는다.
#     - False 면: 표시함
# 3. sns.set_context() 함수
#   - 전체 스케일 조정
#   - paper, notebook, talk, poster. 여기서 기본값은 notebook이다.
#   - 스케일로도 전반적인 사이즈를 조정할 수 있지만 실제 폰트 크기를 조정하는 파라미터는 별도로 있음
#   - sns.set_context() 안에 font_scale 사용

# %%
#seaborn이용한 style 설정
x=np.linspace(1,14,100)

y1 = np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show();

# %%
#seaborn이용한 style 설정
x=np.linspace(1,14,100)

y1 = np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('dark') # 배경
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show();

# %%
#sns.despin() 함수
#축선 표시 여부 결정하는 함수(right=T/F,left=T/F,top=T/F,bottom=T/F)
#각 속성값이 True 면 : 표시하지 않는다.
#         False 면: 표시함

x=np.linspace(1,14,100)

y1 = np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_style('whitegrid')
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
sns.despine(right=True, left=False) # top,bottom=False 가 기본값
plt.show();

# %%
#seaborn이용한 style 설정
x=np.linspace(1,14,100)

y1 = np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk') #paper, notebook,poster
#plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show();

# %%
#seaborn이용한 style 설정
x=np.linspace(1,14,100)

y1 = np.sin(x)
y2=2*np.sin(x)
y3=3*np.sin(x)
y4=4*np.sin(x)

sns.set_context('talk', font_scale=3) #paper, notebook,poster
plt.figure(figsize=(10,6))
plt.plot(x,y1,x,y2,x,y3,x,y4)
plt.show();

# %%
sns.set_context('notebook')

# %% [markdown]
# ## sns 의 기본 데이터 셋 : tips 활용
# - 요일별 점심 저녁 식사 금액과 팁을 정리한 데이터 셋
# - 성별, 흡연여부가 구별되어 있음
# - 패키지명.load_dataset(데이터셋명)

# %%
tips = sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Distribution Plot
# - Distribution Plot은 데이터의 분포를 시각화하는데 도움이 됨
# - 이 그래프를 사용하여 데이터의 평균(mean), 중위수(median), 범위(range), 분산(variance), 편차(deviation)등을 이해 할 수 있음
# 1. Hist Plot
# - 변수에 대한 히스토그램을 표시한다.
# - 하나 혹은 두 개의 변수 분포를 나타내는 전형적인 시각화 도구로 범위에 포함되는 관측수를 세어 표시한다.

# %%
sns.histplot(x=tips['total_bill']);

# %% [markdown]
# 2. KDE Plot
# - 하나 혹은 두 개의 변수에 대한 분포를 그림
# - histplot은 절대량이라면 kdeplot은 밀도 추정치를 시각화
#   - 결과물로는 연속된 곡선의 그래프를 얻을 수 있음

# %%
sns.kdeplot(x=tips['total_bill']);

# %% [markdown]
# 3. Box Plot
# - 최대(maximum), 최소(minimum), mean(평균), 1 사분위수(first quartile), 3 사분위수(third quartile)를 보기 위한 그래프
# - 특이치(outliar)를 발견하기에도 좋다.
# - 단일 연속형 변수에 대해 수치를 표시하거나, 연속형 변수를 기반으로 서로 다른 범주형 변수를 분석할 수 있다.

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))
sns.boxplot(x=tips['total_bill'])
sns.despine()
plt.show();

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기
#요일별 영수증 금액의 분포 확인

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))

sns.boxplot(x=tips['day'], y=tips['total_bill'])
sns.despine(offset=10) # x,y 축간의 간격을 설정하는 인수
plt.show();

# %%
#tips 데이터를 이용한 box plot 그리기
#seaborn 패키지의 boxplot() 이용해서 그리기
#요일별 영수증 금액의 분포 확인
#palette 인수 사용 예제 : palette = '파레트명'

sns.set_style('whitegrid')

plt.figure(figsize=(10,6))

#sns.boxplot(x=tips['day'], y=tips['total_bill'],palette='Set2')
sns.boxplot(x='day', y='total_bill',data=tips,palette='Set2')
sns.despine(offset=10) # x,y 축간의 간격을 설정하는 인수
plt.show();

# %%
#hue 인수 : 카테고리값을 가지는 변수의 이름 지정하면
#카테고리에 따라 그룹을 만들어서 표시

plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='tip',hue='smoker',data=tips,palette='Set3')
plt.show();

# %%
#hue 인수 : 카테고리값을 가지는 변수의 이름 지정하면
#카테고리에 따라 그룹을 만들어서 표시
#y값을 total_bill 필드로 변경 후 비교

plt.figure(figsize=(10,6))
sns.boxplot(x='day', y='total_bill',hue='sex',data=tips,palette='Set3')
plt.show();

# %%
#요일별 팁의 분포를 비교하는 box plot을 그리시오. 파레트 Set3
sns.boxplot(x='day', y='tip',data=tips,palette='Set3');

# %%
#요일별 팁의 분포를 비교하되 성별에 따라 분포를
#나누어 표시하시오.파레트 세트 3
sns.boxplot(x='day', y='tip',hue='sex',data=tips,palette='Set3');

# %%
#위 그래프의 색상값을 파레트 husl 로 변경하시오.
sns.boxplot(x='day', y='tip',hue='sex',data=tips,palette='husl');

# %%
#요일별 영수증 금액의 분포를 비교하되 성별에 따라 분포를
#나누어 표시하시오. 파레트는 임의 사용
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips,palette='Set3');

# %% [markdown]
# 4. Swarm Plot
# - 데이터 포인트 수와 함께 각 데이터의 분포도 제공한다.

# %%
#데이터가 모여 있는 정도를 보여주는 plot : seaborn.swarmplot()
plt.figure(figsize=(10,6))
sns.swarmplot(x='day',y='total_bill',data=tips,palette='husl')
plt.show();

# %%
#box plot과 swarmplot을 같이 사용하는 예제
plt.figure(figsize=(10,6))
sns.boxplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,palette='husl')
plt.show();

# %% [markdown]
# ### seaborn.lmplot()
# - 스캐터그래프를 그릴때 회귀선을 기본으로 출력해주는 그래프 함수
# - size 인수 : 그래프 크기
#   - height 인수로 변경해서 사용하라는 메시지가 출력될 수 있음
# - hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의 그래프에 두개의 값을 모두 표현
# - col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의 개수만큼 그래프를 생성해서 표현한다

# %%
#dataset : tips 사용
sns.set_style('darkgrid')
#plt.scatter(x=tips['total_bill'],y=['tip'])
sns.lmplot(x='total_bill',y='tip',data=tips)
plt.show();

# %%
#dataset : tips 사용
#회귀선 생략 코드 : 인수 : fit_reg=False
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip',data=tips, fit_reg=False)
plt.show();

# %%
#hue 는 그룹을 만듬
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=tips)
plt.show();

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현, 성별 구분
sns.set_style('darkgrid')
sns.lmplot(x='total_bill',y='tip',hue='sex',data=tips)
plt.show();

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되,
#성별을 구분해서 표현하되 그래프를 각각 그리시오.
#hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의
#그래프에 두개의 값을 모두 표현
#col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의
#개수만큼 그래프를 생성해서 표현한다.
sns.lmplot(x='total_bill',y='tip',col='sex',data=tips)
plt.show();

# %%
#영수증 금액과 팁의 관계성을 lmplot()으로 표현하되,
#성별을 구분해서 표현하되 그래프를 각각 그리시오.
#hue 인수 : 카테고리 데이터를 분류하여 그룹화하되 하나의
#그래프에 두개의 값을 모두 표현
#col 인수 : 카테고리 데이터를 분류하여 그룹화하되 그룹의
#개수만큼 그래프를 생성해서 표현한다.
sns.lmplot(x='total_bill',y='tip',col='smoker',data=tips)
plt.show();

# %% [markdown]
# ### heatmap 그래프
# - 히트맵 (heat map)
#   - 열분포도
#   - 2차원 수치 데이터를 색으로 표시
# - 두개의 카테고리 값에 대한 값 변화를 한 눈에 알기 쉬움
# - 대용량 데이터 시각화에도 사용성이 높음
#
# - sns.heatmap
# - heat, # 전처리한 데이터프레임
# - annot = True, # 숫자 표시 여부
# - ax = ax, # 히트맵을 그릴 격자
# - linewidths = 0.4, # 선의 굵기
# - linecolor = 'white', # 선의 색깔
# - fmt = '.1f', # 소수점 포맷팅 형태
# - cmap = 'YlOrRd' # colormap 형태

# %%
# heatmap 그래프 예제
#예제 데이터 생성
uniform_data = np.random.rand(10,12)
uniform_data
# Out:
# array([[0.62109654, 0.44581365, 0.75334792, 0.06168739, 0.17040448,
#         0.96103978, 0.90903431, 0.86986926, 0.93106834, 0.87072855,
#         0.56405123, 0.07766031],
#        [0.78545657, 0.12243578, 0.89637082, 0.67466651, 0.38753001,
#         0.84900001, 0.08902853, 0.58466181, 0.81339655, 0.16626288,
#         0.51586851, 0.8269401 ],
#        [0.83187542, 0.91063401, 0.93059485, 0.70470526, 0.53414115,
#         0.22730089, 0.79863341, 0.24764897, 0.11315054, 0.57549864,
#         0.82665633, 0.94439468],
#        [0.77845439, 0.19858096, 0.11660215, 0.45069889, 0.34165472,
#         0.72429975, 0.59591381, 0.81458503, 0.31797337, 0.65648197,
#         0.19700544, 0.28527556],
#        [0.50059936, 0.24257445, 0.82211935, 0.02360656, 0.88738491,
#         0.90769775, 0.81043576, 0.32373494, 0.26036085, 0.91799132,
#         0.18043626, 0.79844379],
#        [0.10676981, 0.39921174, 0.99357867, 0.14836849, 0.26428747,
#         0.77188214, 0.49360615, 0.45307422, 0.40976425, 0.74707171,
#         0.21103645, 0.84765422],
#        [0.9324452 , 0.66770986, 0.73949193, 0.72197017, 0.07102335,
#         0.23588918, 0.10091271, 0.32943145, 0.08665877, 0.53379704,
#         0.98118317, 0.32105603],
#        [0.20525442, 0.65011008, 0.26567425, 0.80250459, 0.85972329,
#         0.98481104, 0.62142018, 0.32641865, 0.62535133, 0.6484527 ,
#         0.65735261, 0.18363425],
#        [0.17055638, 0.68803339, 0.63039776, 0.53347534, 0.57773753,
#         0.12899004, 0.15720481, 0.06963416, 0.66389956, 0.28563914,
#         0.74438612, 0.34720485],
#        [0.89526039, 0.58578872, 0.2820957 , 0.16686642, 0.26309834,
#         0.07781259, 0.31277248, 0.58621731, 0.95151153, 0.50612289,
#         0.40613788, 0.02799729]])

# %%
sns.heatmap(uniform_data, vmin=0, vmax=1);# 색상 스케일 최소, 최대값

# %% [markdown]
# ### 상관 행렬을 통한 heatmap 활용 예제

# %%
# 상관행렬 생성
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#히트맵으로 표현
sns.heatmap(tips.corr(),annot=True,cmap='viridis');

# %%
#sns 패키지의 filghts data set 을 이용해서 heatmap 작성
flights = sns.load_dataset('flights')
flights.head()
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
#pivot 테이블을 이용해서 연도별 각 월 승객수로 구조를 변환
flight_p=pd.pivot_table(flights,
                       index='month',
                       columns='year',
                       values='passengers',
                       fill_value=0)
flight_p
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
plt.figure(figsize=(10,6))
sns.heatmap(flight_p)
plt.title('연도/월별 승객수')
plt.show();

# %%
#히트맵 그래프 위에 실제 데이터출력
#사용인수 : annot=True, fmt=d/f - 출력데이터 형태
plt.figure(figsize=(10,6))
sns.heatmap(flight_p,annot=True,fmt='d')
plt.title('연도/월별 승객수')
plt.show();

# %% [markdown]
# ## FOLIUM 패키지
# - 지도 이용해 data 시각화 하는 도구
# - 아나콘다 프롬프트에서 설치
#   - pip install folium : 주로 사용
#   - pip install Folium
# - OPEN STREET MAP과 같은 지도 데이터에 leaflet.js 를 이용해서 위치 정보를 시각화 하기 위한 라이브러리
# - 마커형태로 위치정보를 지도상에 표현할 수 있다

# %% [markdown]
# ### 지도 생성 방법
# - Map()메소드에 중심 좌표값을 지정해서 간단하게 생성
# - 위도와 경도를 data로 지도를 그려줌
# - 크롬에서는 출력이 가능하고
# - 익스플로러에서는 저장만 가능(출력되지 않는다.)

# %%
# 초기 map 생성
#중심좌표 인수 location=[lon,lat]
#확대비율 정의 인수 zoon_start=13

map_osm=folium.Map(location=[45.5236,-122.6750],zoom_start=13)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00b6689c8d498a92d36bb82fa7292c78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00b6689c8d498a92d36bb82fa7292c78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00b6689c8d498a92d36bb82fa7292c78 = L.map(
#                 &quot;map_00b6689c8d498a92d36bb82fa7292c78&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73e1fe8d309a57cd0d9995fa48dd26a4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_00b6689c8d498a92d36bb82fa7292c78);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#지도 스타일 변경 :
#Open Street Map을 기반으로 동작하고
#내부적으로 스타일 2개를 지원
#관련인수 tiles= Stamen Toner/ Stamen Terrain
map_osm=folium.Map(location=[45.5236,-122.6750],
                   zoom_start=13,
                  tiles='Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a8b6dd7610f1165eb31894e1222e97e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a8b6dd7610f1165eb31894e1222e97e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a8b6dd7610f1165eb31894e1222e97e = L.map(
#                 &quot;map_2a8b6dd7610f1165eb31894e1222e97e&quot;,
#                 {
#                     center: [45.5236, -122.675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec539442b27703aea751c4bb62848a03 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2a8b6dd7610f1165eb31894e1222e97e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 마커설정(popup 설정도 가능)
#   - 마커(특정 위치를 표시하는 표식)
#   - popup(마커 클릭시에 나타나는 정보) : 환경에 따라 지원안되는 경우도 있음
# 1. 마커 생성
#   - folium.Marker():인자값 위,경도 값 리스트, popup 문자
# 2. 마커 생성 후 부착 하는 코드
#   - folium.Marker().add_to(지도객체변수)

# %%
#한글은 깨져서 나오므로 추가 패키지 설치해야 함
#folium 버전 업그레이드시 해결 될 예정
# 한글 제대로 처리 됨
map_1=folium.Map(location=[45.372,-121.6972],
                 zoom_start=11,
                 tiles='Stamen Terrain')
folium.Marker([45.3288,-121.6625],popup='Hood 산',
              icon=folium.Icon(icon='cloud')).add_to(map_1)
folium.Marker([45.3311,-121.7113],popup='Timberline Lodge',
              icon=folium.Icon(color='red')).add_to(map_1)
folium.Marker([45.3300,-121.6823],popup='Some other location',
              icon=folium.Icon(color='green',icon='info-sign')).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_abac1b0a388097ccfdf720e1be778a69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_abac1b0a388097ccfdf720e1be778a69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_abac1b0a388097ccfdf720e1be778a69 = L.map(
#                 &quot;map_abac1b0a388097ccfdf720e1be778a69&quot;,
#                 {
#                     center: [45.372, -121.6972],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0258078e5f61bf2a25035c6152a7ecc2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_abac1b0a388097ccfdf720e1be778a69);
#
#
#             var marker_cfcbe49833f7741caa312e281d36dc49 = L.marker(
#                 [45.3288, -121.6625],
#                 {}
#             ).addTo(map_abac1b0a388097ccfdf720e1be778a69);
#
#
#             var icon_baeca6bdf2f99b0a1b9447d2440dcc91 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cfcbe49833f7741caa312e281d36dc49.setIcon(icon_baeca6bdf2f99b0a1b9447d2440dcc91);
#
#
#         var popup_efddcfaeec4469aac16344ee29364956 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_912ef987d6b548dd9bbd18e0623d3f33 = $(`&lt;div id=&quot;html_912ef987d6b548dd9bbd18e0623d3f33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hood 산&lt;/div&gt;`)[0];
#                 popup_efddcfaeec4469aac16344ee29364956.setContent(html_912ef987d6b548dd9bbd18e0623d3f33);
#
#
#
#         marker_cfcbe49833f7741caa312e281d36dc49.bindPopup(popup_efddcfaeec4469aac16344ee29364956)
#         ;
#
#
#
#
#             var marker_4c1a02a4f84f8bc40d5c0f295a6a1e3c = L.marker(
#                 [45.3311, -121.7113],
#                 {}
#             ).addTo(map_abac1b0a388097ccfdf720e1be778a69);
#
#
#             var icon_a113a34f79b38f02f2dd2c718dc67d50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4c1a02a4f84f8bc40d5c0f295a6a1e3c.setIcon(icon_a113a34f79b38f02f2dd2c718dc67d50);
#
#
#         var popup_608ef3657809b6cf9a4608bba941376a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e4d7c75310241014ed436739c658307 = $(`&lt;div id=&quot;html_2e4d7c75310241014ed436739c658307&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Timberline Lodge&lt;/div&gt;`)[0];
#                 popup_608ef3657809b6cf9a4608bba941376a.setContent(html_2e4d7c75310241014ed436739c658307);
#
#
#
#         marker_4c1a02a4f84f8bc40d5c0f295a6a1e3c.bindPopup(popup_608ef3657809b6cf9a4608bba941376a)
#         ;
#
#
#
#
#             var marker_c562bac1b96a352b85fd35d85d4327d2 = L.marker(
#                 [45.33, -121.6823],
#                 {}
#             ).addTo(map_abac1b0a388097ccfdf720e1be778a69);
#
#
#             var icon_0aac7e2e1c626f8d97619a9333a57429 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c562bac1b96a352b85fd35d85d4327d2.setIcon(icon_0aac7e2e1c626f8d97619a9333a57429);
#
#
#         var popup_6968a05946a5b4b1be9cda204908269c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95c083c63c0a504d410e16cdd869967b = $(`&lt;div id=&quot;html_95c083c63c0a504d410e16cdd869967b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Some other location&lt;/div&gt;`)[0];
#                 popup_6968a05946a5b4b1be9cda204908269c.setContent(html_95c083c63c0a504d410e16cdd869967b);
#
#
#
#         marker_c562bac1b96a352b85fd35d85d4327d2.bindPopup(popup_6968a05946a5b4b1be9cda204908269c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !import

# %%
# @37.579617,126.977041
map_1=folium.Map(location=[37.579617,126.977041],
                 zoom_start=11,
                 tiles='Stamen Terrain')
folium.Marker([37.579617,126.977041],popup='경복궁',
              icon=folium.Icon(icon='cloud')).add_to(map_1)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b769e363bfc4736276db375a55650483 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b769e363bfc4736276db375a55650483&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b769e363bfc4736276db375a55650483 = L.map(
#                 &quot;map_b769e363bfc4736276db375a55650483&quot;,
#                 {
#                     center: [37.579617, 126.977041],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18c4c005ed5a3311c7679057ecb04f41 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b769e363bfc4736276db375a55650483);
#
#
#             var marker_653d3715f9e0579fac26d570f5d6a129 = L.marker(
#                 [37.579617, 126.977041],
#                 {}
#             ).addTo(map_b769e363bfc4736276db375a55650483);
#
#
#             var icon_fb9d184d1145cc60edb50c1b84424e0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_653d3715f9e0579fac26d570f5d6a129.setIcon(icon_fb9d184d1145cc60edb50c1b84424e0d);
#
#
#         var popup_c9a2110c289e23ae30e252cf94d2a1fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_543e747cb4caceed9d4863b0cb44c5b8 = $(`&lt;div id=&quot;html_543e747cb4caceed9d4863b0cb44c5b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_c9a2110c289e23ae30e252cf94d2a1fc.setContent(html_543e747cb4caceed9d4863b0cb44c5b8);
#
#
#
#         marker_653d3715f9e0579fac26d570f5d6a129.bindPopup(popup_c9a2110c289e23ae30e252cf94d2a1fc)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 단계 구분도
# - 데이터를 지도 그림에 반영시켜서 전달하는 그래프
# - 보통 folium 에 layer로 얹게 된다.
# - map 객체의 choropleth() 이용해서 작업
# - 사용 인수
#   - geo_data : 지도 파일 경로와 파일명
#   - data : 지도에 표현되어야 할 값 변수
#   - columns = [key로 사용할 data, 실제 data의 필드명]
#   - key_on : 지도 경계파일인 json에서 사용할 키 값이며 지도 Data는 표준 형식으로 만들어 져야 함
#     - key_on 지칭 문법 : feature(키워드).json에서 나타나키 필드명
# - folium.LayerControl().add_to(map) : 단계구분도를 map에 표시하는 함수

# %%
# 미국 각 주별 실업율을 data로 단계 구분도 작성
#지도 경계 data가 있어야 함.json 파일로 작성됨

# %%
#관련 data 가져오기
state_unemployment='02. folium_US_Unemployment_Oct2012.csv'
state_unemp_data=pd.read_csv(state_unemployment)
state_unemp_data.head()
# 50개 주 실업률 data
# Out:
#   State  Unemployment
# 0    AL           7.1
# 1    AK           6.8
# 2    AZ           8.1
# 3    AR           7.2
# 4    CA          10.1

# %%
state_geo='02. folium_us-states.json'
state_geo
# Out:
# '02. folium_us-states.json'

# %%
map = folium.Map(location=[40,-98],zoom_start=3)
# map
map.choropleth(geo_data=state_geo,
              data=state_unemp_data,
              columns=['State','Unemployment'],
              key_on='feature.id',
              fill_color='YlGn',
              legend_name='Unemployment Rate(%)')
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0ed2dc0546d24f43bc3000b3263a2ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0ed2dc0546d24f43bc3000b3263a2ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0ed2dc0546d24f43bc3000b3263a2ff = L.map(
#                 &quot;map_c0ed2dc0546d24f43bc3000b3263a2ff&quot;,
#                 {
#                     center: [40.0, -98.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba0b1d6d51a8e9d34556946633222c24 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c0ed2dc0546d24f43bc3000b3263a2ff);
#
#
#             var choropleth_ddf523db0521d70511f2c95657337276 = L.featureGroup(
#                 {}
#             ).addTo(map_c0ed2dc0546d24f43bc3000b3263a2ff);
#
#
#         function geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;NE&quot;: case &quot;ND&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96 = L.geoJson(null, {
#                 onEachFeature: geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96_onEachFeature,
#
#                 style: geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96_styler,
#         });
#
#         function geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96_add (data) {
#             geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96
#                 .addData(data)
#                 .addTo(choropleth_ddf523db0521d70511f2c95657337276);
#         }
#             geo_json_dc3c1aeea8ffc518a8b9336fb8a26d96_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;AL&quot;, &quot

# %%
#한국 지도 데이터 이용해서 단계 구분도 그리기
#한국지도 경계의 json data 파일 가져오기
#한글이 포함된경우에는 그냥 path만 연결하면 인코딩 문제 발생
#json.load( encoding='utf-8') 이용해서 변수에 data 저장 후 사용하는 것이 일반적

geo_path='02. skorea_municipalities_geo_simple.json'
geo_str=json.load(open(geo_path,encoding='utf-8'))
geo_str
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': '강동구',
#    'properties': {'code': '11250',
#     'name': '강동구',
#     'name_eng': 'Gangdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.11519584981606, 37.557533180704915],
#       [127.16683184366129, 37.57672487388627],
#       [127.18408792330152, 37.55814280369575],
#       [127.16530984307447, 37.54221851258693],
#       [127.14672806823502, 37.51415680680291],
#       [127.12123165719615, 37.52528270089],
#       [127.1116764203608, 37.540669955324965],
#       [127.11519584981606, 37.557533180704915]]]}},
#   {'type': 'Feature',
#    'id': '송파구',
#    'properties': {'code': '11240',
#     'name': '송파구',
#     'name_eng': 'Songpa-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0690698130372, 37.522279423505026],
#       [127.10087519791962, 37.524841220167055],
#       [127.1116764203608, 37.540669955324965],
#       [127.12123165719615, 37.52528270089],
#       [127.14672806823502, 37.51415680680291],
#       [127.1634944215765, 37.497445406097484],
#       [127.14206058413274, 37.47089819098501],
#       [127.12440571080893, 37.46240445587048],
#       [127.11117085201238, 37.485708381512445],
#       [127.0719146000724, 37.50224013587669],
#       [127.0690698130372, 37.522279423505026]]]}},
#   {'type': 'Feature',
#    'id': '강남구',
#    'properties': {'code': '11230',
#     'name': '강남구',
#     'name_eng': 'Gangnam-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.05867359288398, 37.52629974922568],
#       [127.0690698130372, 37.522279423505026],
#       [127.0719146000724, 37.50224013587669],
#       [127.11117085201238, 37.485708381512445],
#       [127.12440571080893, 37.46240445587048],
#       [127.09842759318751, 37.45862253857461],
#       [127.08640440578156, 37.472697935184655],
#       [127.0559170481904, 37.4659228914077],
#       [127.03621915098798, 37.48175802427603],
#       [127.01397119667513, 37.52503988289669],
#       [127.02302831890559, 37.53231899582663],
#       [127.05867359288398, 37.52629974922568]]]}},
#   {'type': 'Feature',
#    'id': '서초구',
#    'properties': {'code': '11220',
#     'name': '서초구',
#     'name_eng': 'Seocho-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.01397119667513, 37.52503988289669],
#       [127.03621915098798, 37.48175802427603],
#       [127.0559170481904, 37.4659228914077],
#       [127.08640440578156, 37.472697935184655],
#       [127.09842759318751, 37.45862253857461],
#       [127.09046928565951, 37.44296826114185],
#       [127.06778107605433, 37.426197424057314],
#       [127.04957232987142, 37.42805836845694],
#       [127.03881782597922, 37.45382039851715],
#       [126.99072073195462, 37.455326143310025],
#       [126.98367668291802, 37.473856492692086],
#       [126.98223807916081, 37.509314966770326],
#       [127.01397119667513, 37.52503988289669]]]}},
#   {'type': 'Feature',
#    'id': '관악구',
#    'properties': {'code': '11210',
#     'name': '관악구',
#     'name_eng': 'Gwanak-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.98367668291802, 37.473856492692086],
#       [126.99072073195462, 37.455326143310025],
#       [126.96520439085143, 37.438249784006246],
#       [126.95000001010182, 37.43613451165719],
#       [126.93084408056525, 37.447382928333994],
#       [126.9167728146601, 37.45490566423789],
#       [126.90156094129895, 37.47753842789901],
#       [126.90531975801812, 37.48218087575429],
#       [126.94922661389508, 37.49125437495649],
#       [126.9725891850662, 37.472561363278125],
#       [126.98367668291802, 37.473856492692086]]]}},
#   {'type': 'Feature',
#    'id': '동작구',
#    'properties': {'code': '11200',
#     'name': '동작구',
#     'name_eng': 'Dongjak-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.98223807916081, 37.509314966770326],
#       [126.98367668291802, 37.473856492692086],
#       [126.9725891850662, 37.472561363278125],
#       [126.94922661389508, 37.49125437495649],
#       [126.90531975801812, 37.48218087575429],
#       [126.92177893174825, 37.494889877415176],
#       [126.92810628828279, 37.51329595732015],
#       [126.95249990298159, 37.51722500741813],
#       [126.98223807916081, 37.509314966770326]]]}},
#   {'type': 'Feature',
#    'id': '영등포구',
#    'properties': {'code': '11190',
#     'name': '영등포구',
#     'name_eng': 'Yeongdeungpo-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.89184663862764, 37.547373974997114],
#       [126.94566733083212, 37.526617542453366],
#       [126.95249990298159, 37.51722500741813],
#       [126.92810628828279, 37.51329595732015],
#       [126.92177893174825, 37.494889877415176],
#       [126.90531975801812, 37.48218087575429],
#       [126.89594776782485, 37.504675281309176],
#       [126.88156402353862, 37.513970034765684],
#       [126.88825757860099, 37.54079733630232],
#       [126.89184663862764, 37.547373974997114]]]}},
#   {'type': 'Feature',
#    'id': '금천구',
#    'properties': {'code': '11180',
#     'name': '금천구',
#     'name_eng': 'Geumcheon-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.90156094129895, 37.47753842789901],
#       [126.9167728146601, 37.45490566423789],
#       [126.93084408056525, 37.447382928333994],
#       [126.9025831711697, 37.434549366349124],
#       [126.87683271502428, 37.482576591607305],
#       [126.90156094129895, 37.47753842789901]]]}},
#   {'type': 'Feature',
#    'id': '구로구',
#    'properties': {'code': '11170',
#     'name': '구로구',
#     'name_eng': 'Guro-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.82688081517314, 37.50548972232896],
#       [126.88156402353862, 37.513970034765684],
#       [126.89594776782485, 37.504675281309176],
#       [126.90531975801812, 37.48218087575429],
#       [126.90156094129895, 37.47753842789901],
#       [126.87683271502428, 37.482576591607305],
#       [126.84762676054953, 37.47146723936323],
#       [126.83549485076196, 37.474098236975095],
#       [126.82264796791348, 37.4878476492147],
#       [126.82504736331406, 37.50302612640443],
#       [126.82688081517314, 37.50548972232896]]]}},
#   {'type': 'Feature',
#    'id': '강서구',
#    'properties': {'code': '11160',
#     'name': '강서구',
#     'name_eng': 'Gangseo-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.79575768552907, 37.57881087633202],
#       [126.80702115023597, 37.60123001013228],
#       [126.82251438477105, 37.5880430810082],
#       [126.85984199399667, 37.571847855292745],
#       [126.89184663862764, 37.547373974997114],
#       [126.88825757860099, 37.54079733630232],
#       [126.86637464321238, 37.54859191094823],
#       [126.86610073476395, 37.52699964144669],
#       [126.84257291943153, 37.52373707805596],
#       [126.8242331426722, 37.53788078753248],
#       [126.77324417717703, 37.5459123450554],
#       [126.76979180579352, 37.55139183008809],
#       [126.79575768552907, 37.57881087633202]]]}},
#   {'type': 'Feature',
#    'id': '양천구',
#    'properties': {'code': '11150',
#     'name': '양천구',
#     'name_eng': 'Yangcheon-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.8242331426722, 37.53788078753248],
#       [126.84257291943153, 37.52373707805596],
#       [126.86610073476395, 37.52699964144669],
#       [126.86637464321238, 37.54859191094823],
#       [126.88825757860099, 37.54079733630232],
#       [126.88156402353862, 37.513970034765684],
#       [126.82688081517314, 37.50548972232896],
#       [126.8242331426722, 37.53788078753248]]]}},
#   {'type': 'Feature',
#    'id': '마포구',
#    'properties': {'code': '11140',
#     'name': '마포구',
#     'name_eng': 'Mapo-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.90522065831053, 37.57409700522574],
#       [126.93898161798973, 37.552310003728124],
#       [126.96358226710812, 37.55605635475154],
#       [126.96448570553055, 37.548705692021635],
#       [126.94566733083212, 37.526617542453366],
#       [126.89184663862764, 37.547373974997114],
#       [126.85984199399667, 37.571847855292745],
#       [126.88433284773288, 37.588143322880526],
#       [126.90522065831053, 37.57409700522574]]]}},
#   {'type': 'Feature',
#    'id': '서대문구',
#    'properties': {'code': '11130',
#     'name': '서대문구',
#     'name_eng': 'Seodaemun-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9524752030572, 37.60508692737045],
#       [126.95565425846463, 37.576080790881456],
#       [126.96873633279075, 37.56313604690827],
#       [126.96358226710812, 37.55605635475154],
#       [126.93898161798973, 37.552310003728124],
#       [126.90522065831053, 37.57409700522574],
#       [126.9524752030572, 37.60508692737045]]]}},
#   {'type': 'Feature',
#    'id': '은평구',
#    'properties': {'code': '11120',
#     'name': '은평구',
#     'name_eng': 'Eunpyeong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9738864128702, 37.62949634786888],
#       [126.95427017006129, 37.622033431339425],
#       [126.9524752030572, 37.60508692737045],
#       [126.90522065831053, 37.57409700522574],
#       [126.88433284773288, 37.588143322880526],
#       [126.90396681003595, 37.59227403419942],
#       [126.90303066177668, 37.609977911401344],
#       [126.91455481429648, 37.64150050996935],
#       [126.956473797387, 37.652480737339445],
#       [126.9738864128702, 37.62949634786888]]]}},
#   {'type': 'Feature',
#    'id': '노원구',
#    'properties': {'code': '11110',
#     'name': '노원구',
#     'name_eng': 'Nowon-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.0838752703195, 37.69359534202034],
#       [127.09706391309695, 37.686383719372294],
#       [127.09440766298717, 37.64713490473045],
#       [127.11326795855199, 37.639622905315925],
#       [127.10782277688129, 37.61804244241069],
#       [127.07351243825278, 37.61283660342313],
#       [127.05209373568619, 37.62164065487782],
#       [127.04358800895609, 37.62848931298715],
#       [127.05800075220091, 37.64318263878276],
#       [127.05288479710485, 37.68423857084347],
#       [127.0838752703195, 37.69359534202034]]]}},
#   {'type': 'Feature',
#    'id': '도봉구',
#    'properties': {'code': '11100',
#     'name': '도봉구',
#     'name_eng': 'Dobong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.05288479710485, 37.68423857084347],
#       [127.05800075220091, 37.64318263878276],
#       [127.04358800895609, 37.62848931298715],
#       [127.01465935892466, 37.64943687496812],
#       [127.02062116141389, 37.667173575971205],
#       [127.01039666042071, 37.681894589603594],
#       [127.01795099203432, 37.69824412775662],
#       [127.05288479710485, 37.68423857084347]]]}},
#   {'type': 'Feature',
#    'id': '강북구',
#    'properties': {'code': '11090',
#     'name': '강북구',
#     'name_eng': 'Gangbuk-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.99383903424, 37.676681761199085],
#       [127.01039666042071, 37.681894589603594],
#       [127.02062116141389, 37.667173575971205],
#       [127.01465935892466, 37.64943687496812],
#       [127.04358800895609, 37.62848931298715],
#       [127.05209373568619, 37.62164065487782],
#       [127.03892400992301, 37.609715611023816],
#       [127.0128154749523, 37.613652243470256],
#       [126.98672705513869, 37.63377641288196],
#       [126.9817452676551, 37.65209769387776],
#       [126.99383903424, 37.676681761199085]]]}},
#   {'type': 'Feature',
#    'id': '성북구',
#    'properties': {'code': '11080',
#     'name': '성북구',
#     'name_eng': 'Seongbuk-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.977175406416, 37.62859715400388],
#       [126.98672705513869, 37.63377641288196],
#       [127.0128154749523, 37.613652243470256],
#       [127.03892400992301, 37.609715611023816],
#       [127.05209373568619, 37.62164065487782],
#       [127.07351243825278, 37.61283660342313],
#       [127.07382707099227, 37.60401928986419],
#       [127.042705222094, 37.59239437593391],
#       [127.02527254528003, 37.57524616245249],
#       [126.99348293358314, 37.588565457216156],
#       [126.98879865992384, 37.6118927319756],
#       [126.977175406416, 37.62859715400388]]]}},
#   {'type': 'Feature',
#    'id': '중랑구',
#    'properties': {'code': '11070',
#     'name': '중랑구',
#     'name_eng': 'Jungnang-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.07351243825278, 37.61283660342313],
#       [127.10782277688129, 37.61804244241069],
#       [127.1201246020114, 37.60178457598188],
#       [127.10304174249214, 37.57076342290955],
#       [127.08068541280403, 37.56906425519017],
#       [127.07382707099227, 37.60401928986419],
#       [127.07351243825278, 37.61283660342313]]]}},
#   {'type': 'Feature',
#    'id': '동대문구',
#    'properties': {'code': '11060',
#     'name': '동대문구',
#     'name_eng': 'Dongdaemun-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02527254528003, 37.57524616245249],
#       [127.042705222094, 37.59239437593391],
#       [127.07382707099227, 37.60401928986419],
#       [127.08068541280403, 37.56906425519017],
#       [127.07421053024362, 37.55724769712085],
#       [127.05005601081567, 37.567577612590846],
#       [127.02547266349976, 37.568943552237734],
#       [127.02527254528003, 37.57524616245249]]]}},
#   {'type': 'Feature',
#    'id': '광진구',
#    'properties': {'code': '11050',
#     'name': '광진구',
#     'name_eng': 'Gwangjin-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.08068541280403, 37.56906425519017],
#       [127.10304174249214, 37.57076342290955],
#       [127.11519584981606, 37.557533180704915],
#       [127.1116764203608, 37.540669955324965],
#       [127.10087519791962, 37.524841220167055],
#       [127.0690698130372, 37.522279423505026],
#       [127.05867359288398, 37.52629974922568],
#       [127.07421053024362, 37.55724769712085],
#       [127.08068541280403, 37.56906425519017]]]}},
#   {'type': 'Feature',
#    'id': '성동구',
#    'properties': {'code': '11040',
#     'name': '성동구',
#     'name_eng': 'Seongdong-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02547266349976, 37.568943552237734],
#       [127.05005601081567, 37.567577612590846],
#       [127.07421053024362, 37.55724769712085],
#       [127.05867359288398, 37.52629974922568],
#       [127.02302831890559, 37.53231899582663],
#       [127.01070894177482, 37.54118048964762],
#       [127.02547266349976, 37.568943552237734]]]}},
#   {'type': 'Feature',
#    'id': '용산구',
#    'properties': {'code': '11030',
#     'name': '용산구',
#     'name_eng': 'Yongsan-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.01070894177482, 37.54118048964762],
#       [127.02302831890559, 37.53231899582663],
#       [127.01397119667513, 37.52503988289669],
#       [126.98223807916081, 37.509314966770326],
#       [126.95249990298159, 37.51722500741813],
#       [126.94566733083212, 37.526617542453366],
#       [126.96448570553055, 37.548705692021635],
#       [126.98752996903328, 37.55094818807139],
#       [127.01070894177482, 37.54118048964762]]]}},
#   {'type': 'Feature',
#    'id': '중구',
#    'properties': {'code': '11020',
#     'name': '중구',
#     'name_eng': 'Jung-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[127.02547266349976, 37.568943552237734],
#       [127.01070894177482, 37.54118048964762],
#       [126.98752996903328, 37.55094818807139],
#       [126.96448570553055, 37.548705692021635],
#       [126.96358226710812, 37.55605635475154],
#       [126.96873633279075, 37.56313604690827],
#       [127.02547266349976, 37.568943552237734]]]}},
#   {'type': 'Feature',
#    'id': '종로구',
#    'properties': {'code': '11010',
#     'name': '종로구',
#     'name_eng': 'Jongno-gu',
#     'base_year': '2013'},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[[126.9738864128702, 37.62949634786888],
#       [126.977175406416, 37.62859715400388],
#       [126.98879865992384, 37.6118927319756],
#       [126.99348293358314, 37.588565457216156],
#       [127.02527254528003, 37.57524616245249],
#       [127.02547266349976, 37.568943552237734],
#       [126.96873633279075, 37.56313604690827],
#       [126.95565425846463, 37.576080790881456],
#       [126.9524752030572, 37.60508692737045],
#       [126.95427017006129, 37.622033431339425],
#       [126.9738864128702, 37.62949634786888]]]}}]}

# %%
#서울을 중심으로 기본 지도 출력
#위경도[37.5502,126.982]
map = folium.Map(location=[37.5502,126.982],
            zoom_start=11,
            tiles='Stamen Toner')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b9d03a748abe533cb43de58650448c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b9d03a748abe533cb43de58650448c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4b9d03a748abe533cb43de58650448c = L.map(
#                 &quot;map_d4b9d03a748abe533cb43de58650448c&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3fb2e85d38123cbe55baa78c4f2ca3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4b9d03a748abe533cb43de58650448c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#단계 구분도 data 읽어오기
#csv 읽어오기 : pd.read_csv(경로포함파일명,encoding=,index_col='지정인덱스 필드명')
f_test=pd.read_csv('cctv_result.csv', encoding='utf-8',index_col='구별')
f_test.head()
# Out:
#        소계       최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0  0.867660
# 강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0  0.929765
# 강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0  1.061806
# 강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0  1.080540
# 관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율    CCTV비율           오차
# 구별
# 강남구  11.072217  0.487292  1388.055355
# 강동구  12.051638  0.170552   465.422892
# 강북구  16.600342  0.226535   329.342026
# 강서구  12.015794  0.146413   551.503155
# 관악구  12.955291  0.284673   162.948104

# %%
map.choropleth(geo_data=geo_str,
              data=f_test,
              columns=[f_test.index,'소계'],
              key_on='feature.id',
              fill_color='PuRd',
              legend_name='CCTV 현황')
folium.LayerControl().add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b9d03a748abe533cb43de58650448c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b9d03a748abe533cb43de58650448c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4b9d03a748abe533cb43de58650448c = L.map(
#                 &quot;map_d4b9d03a748abe533cb43de58650448c&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3fb2e85d38123cbe55baa78c4f2ca3 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d4b9d03a748abe533cb43de58650448c);
#
#
#             var choropleth_fdaeb5303383006724fb315dff872d5c = L.featureGroup(
#                 {}
#             ).addTo(map_d4b9d03a748abe533cb43de58650448c);
#
#
#         function geo_json_b81df791e670a7c93fd2025c505abc12_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c994c7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b81df791e670a7c93fd2025c505abc12_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b81df791e670a7c93fd2025c505abc12 = L.geoJson(null, {
#                 onEachFeature: geo_json_b81df791e670a7c93fd2025c505abc12_onEachFeature,
#
#                 style: geo_json_b81df791e670a7c93fd2025c505abc12_styler,
#         });
#
#         function geo_json_b81df791e670a7c93fd2025c505abc12_add (data) {
#             geo_json_b81df791e670a7c93fd2025c505abc12
#                 .addData(data)
#                 .addTo(choropleth_fdaeb5303383006724fb315dff872d5c);
#         }
#             geo_json_b81df791e670a7c93fd2025c505abc12_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [1
